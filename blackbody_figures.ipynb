# %%
from astropy.io import ascii
import astropy.table as table
import os 
import numpy as np 
import pandas
import glob
import matplotlib.pyplot as plt
import sys 
path = '/home/idoi/Dropbox/Objects/ZTF22aasxgjp/public code/to upload/'
sys.path.append(path) 
from PhotoUtils import *
plt.rcParams.update({
  "text.usetex": True,
})
from Ni_tools import *

# %%
Temps_2021gno = ascii.read(path+'/test_files/bb_2021gno.txt')
Temps_2022oqm = ascii.read(path+'/test_files/bb_2022oqm.txt')
Temps_2020bvc = ascii.read(path+'/test_files/bb_2020bvc.txt')
Temps_2006aj  = ascii.read(path+'/test_files/bb_2006aj.txt')
Temps_2020oi  = ascii.read(path+'/test_files/bb_2020oi.txt')
Temps_2018gep = ascii.read(path+'/test_files/bb_2018gep.txt')
Temps_2019hgp = ascii.read(path+'/test_files/bb_2019hgp.txt')
Temps_2014ft  = ascii.read(path+'/test_files/bb_2014ft.txt')
Temps_2020scb = ascii.read(path+'/test_files/bb_2020scb.txt')
Temps_2021csp = ascii.read(path+'/test_files/bb_2021csp.txt')


z = 0.0113
t0_oqm = 2459771.21688075
Temps_2022oqm['t_rest'] = (Temps_2022oqm['JD'] - t0_oqm)/(1+z)
marker = '*'
markersize = 6


m_sn =   {'2006aj':'^'
         ,'2014ft':'o'
         ,'2019hgp':'P'
         ,'2022oqm':'p'
         ,'2020bvc':'*'
         ,'2018gep':'d'
         ,'2020oi':'s'
         ,'2020scb':'X'
         ,'2021csp':'o'
         ,'2021gno':'D'}


f_sn =   {'2006aj' :'full'
         ,'2014ft' :'none'
         ,'2019hgp':'full'
         ,'2022oqm':'full'
         ,'2020bvc':'none'
         ,'2018gep':'none'
         ,'2020oi' :'none'
         ,'2020scb':'left'
         ,'2021csp':'full'
         ,'2021gno':'left'}

# %%
### plot blackbody evolution of various SNe Ic, Ic-BL, Ca-Ib, and Icn

time = np.logspace(-0.9,2,100)
plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.errorbar(Temps_2018gep['t_rest'],Temps_2018gep['T'],np.vstack([Temps_2018gep['T'] - Temps_2018gep['T_down'],Temps_2018gep['T_up']-Temps_2018gep['T']]),marker = m_sn['2018gep'],fillstyle = f_sn['2018gep'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'b', label = '2018gep')
plt.errorbar(Temps_2022oqm['t_rest'],Temps_2022oqm['T'],np.vstack([Temps_2022oqm['T'] -Temps_2022oqm['T_down'],Temps_2022oqm['T_up']-Temps_2022oqm['T']]) ,marker = m_sn['2022oqm'],fillstyle = f_sn['2022oqm'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'r', label = r'SN2022oqm')
plt.errorbar(Temps_2019hgp['t_rest'],Temps_2019hgp['T'],np.vstack([Temps_2019hgp['T'] -Temps_2019hgp['T_down'],Temps_2019hgp['T_up']-Temps_2019hgp['T']]) ,marker = m_sn['2019hgp'],fillstyle = f_sn['2019hgp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'g', label = r'SN2019hgp')
plt.errorbar(Temps_2020bvc['t_rest'],Temps_2020bvc['T'],np.vstack([Temps_2020bvc['T'] - Temps_2020bvc['T_down'],Temps_2020bvc['T_up']-Temps_2020bvc['T']]),marker = m_sn['2020bvc'],fillstyle = f_sn['2020bvc'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'k', label = '2020bvc')
plt.errorbar(Temps_2020oi['t_rest'],Temps_2020oi['T'],np.vstack([Temps_2020oi['T'] - Temps_2020oi['T_down'],Temps_2020oi['T_up']-Temps_2020oi['T']])      ,marker = m_sn['2020oi' ],fillstyle = f_sn['2020oi' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'c', label = '2020oi')
plt.errorbar(Temps_2006aj['t_rest'],Temps_2006aj['T'],np.vstack([Temps_2006aj['T'] - Temps_2006aj['T_down'],Temps_2006aj['T_up']-Temps_2006aj['T']])      ,marker = m_sn['2006aj' ],fillstyle = f_sn['2006aj' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'm', label = '2006aj')
plt.errorbar(Temps_2014ft['t_rest'],Temps_2014ft['T'],np.vstack([Temps_2014ft['T'] - Temps_2014ft['T_down'],Temps_2014ft['T_up']-Temps_2014ft['T']])      ,marker = m_sn['2014ft' ],fillstyle = f_sn['2014ft' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'y', label = '2014ft')
plt.errorbar(Temps_2020scb['t_rest'],Temps_2020scb['T'],np.vstack([Temps_2020scb['T'] - Temps_2020scb['T_down'],Temps_2020scb['T_up']-Temps_2020scb['T']]),marker = m_sn['2020scb'],fillstyle = f_sn['2020scb'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#FFB600', label = '2020scb')
plt.errorbar(Temps_2021csp['t_rest'],Temps_2021csp['T'],np.vstack([Temps_2021csp['T'] - Temps_2021csp['T_down'],Temps_2021csp['T_up']-Temps_2021csp['T']]),marker = m_sn['2021csp'],fillstyle = f_sn['2021csp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#B80043', label = '2021csp (Icn)')
plt.errorbar(Temps_2021gno['t_rest'],Temps_2021gno['T'],np.vstack([Temps_2021gno['T'] - Temps_2021gno['T_down'],Temps_2021gno['T_up']-Temps_2021gno['T']]),marker = m_sn['2021gno'],fillstyle = f_sn['2021gno'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#9EDF13', label = '2021gno (Ca-Ib)')

plt.xlabel('Rest-frame days from estimated explosion',fontsize = 14)
plt.ylabel('T [$^{\circ}K$]',fontsize = 14)
plt.yscale('log')
plt.xscale('log')
#plt.legend(loc = 1)
plt.xlim((0.25,50))
plt.ylim((4e3,1e5))

plt.subplot(1,3,2)
plt.errorbar(Temps_2018gep['t_rest'],Temps_2018gep['L_bol_w_extrap'],Temps_2018gep['L_bol_w_extrap_err']      ,marker = m_sn['2018gep'],fillstyle = f_sn['2018gep'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'b', label = 'SN2018gep (Ic-BL)')
plt.errorbar(Temps_2022oqm['t_rest'],Temps_2022oqm['L_bol_w_extrap'],Temps_2022oqm['L_bol_w_extrap_err']      ,marker = m_sn['2022oqm'],fillstyle = f_sn['2022oqm'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'r', label = r'SN2022oqm (Ic)')
plt.errorbar(Temps_2019hgp['t_rest'],Temps_2019hgp['L_bol_w_extrap'],Temps_2019hgp['L_bol_w_extrap_err']      ,marker = m_sn['2019hgp'],fillstyle = f_sn['2019hgp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'g', label = r'SN2019hgp (Icn)')
plt.errorbar(Temps_2020bvc['t_rest'],Temps_2020bvc['L_bol_w_extrap'],Temps_2020bvc['L_bol_w_extrap_err']      ,marker = m_sn['2020bvc'],fillstyle = f_sn['2020bvc'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'k', label = '2020bvc  (Ic-BL)')
plt.errorbar(Temps_2020oi ['t_rest'],Temps_2020oi ['L_bol_w_extrap'],Temps_2020oi ['L_bol_w_extrap_err']      ,marker = m_sn['2020oi' ],fillstyle = f_sn['2020oi' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'c', label = '2020oi (Ic)')
plt.errorbar(Temps_2006aj ['t_rest'],Temps_2006aj ['L_bol_w_extrap'],Temps_2006aj ['L_bol_w_extrap_err']      ,marker = m_sn['2006aj' ],fillstyle = f_sn['2006aj' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'm', label = '2006aj  (Ic-BL)')
plt.errorbar(Temps_2014ft ['t_rest'],Temps_2014ft ['L_bol_w_extrap'],Temps_2014ft ['L_bol_w_extrap_err']      ,marker = m_sn['2014ft' ],fillstyle = f_sn['2014ft' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'y', label = '2014ft  (US-Ic)')
plt.errorbar(Temps_2020scb ['t_rest'],Temps_2020scb ['L_bol_w_extrap'],Temps_2020scb ['L_bol_w_extrap_err']   ,marker = m_sn['2020scb'],fillstyle = f_sn['2020scb'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#FFB600', label = '2020scb (Ic)')
plt.errorbar(Temps_2021csp ['t_rest'],Temps_2021csp ['L_bol_w_extrap'],Temps_2021csp ['L_bol_w_extrap_err']   ,marker = m_sn['2021csp'],fillstyle = f_sn['2021csp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#B80043', label = '2021csp (Icn)')
plt.errorbar(Temps_2021gno['t_rest'],Temps_2021gno['L_bol_w_extrap'],Temps_2021gno['L_bol_w_extrap_err']      ,marker = m_sn['2021gno'],fillstyle = f_sn['2021gno'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = '#9EDF13', label = '2021gno (Ca-Ib)')
plt.xlabel('Rest-frame days from estimated explosion',fontsize = 14)

plt.ylabel('L [erg/s]',fontsize = 14)


plt.yscale('log')
plt.xscale('log')
plt.legend(loc = 1)
plt.xlim((0.25,50))
plt.ylim((1e41,1e46))

plt.subplot(1,3,3)
plt.plot(time,  1e9*24*3600*time   ,'k',alpha = 0.5, label = '')#  'v=10,000 $km\ s^{-1}$ ')
plt.plot(time,  2e9*24*3600*time   ,'k',alpha = 0.5, label = '')#  'v=20,000 $km\ s^{-1}$ ')
plt.plot(time,  3e9*24*3600*time   ,'k',alpha = 0.5, label = '')#  'v=30,000 $km\ s^{-1}$ ')
plt.plot(time,  4e9*24*3600*time   ,'k',alpha = 0.5, label = '')#  'v=40,000 $km\ s^{-1}$ ')
plt.text(32,  1.3*1e9*24*3600*30,r'10,000 $km\ s^{-1}$'   ,color = 'k',alpha = 0.8, rotation = 56)#  'v=10,000 $km\ s^{-1}$ ')
plt.text(32,  1.3*2e9*24*3600*30,r'20,000 $km\ s^{-1}$'   ,color = 'k',alpha = 0.8, rotation = 56)#  'v=20,000 $km\ s^{-1}$ ')
plt.text(32,  1.3*3e9*24*3600*30,r'30,000 $km\ s^{-1}$'   ,color = 'k',alpha = 0.8, rotation = 56)#  'v=30,000 $km\ s^{-1}$ ')
plt.text(32,  1.3*4e9*24*3600*30,r'40,000 $km\ s^{-1}$'   ,color = 'k',alpha = 0.8, rotation = 56)#  'v=40,000 $km\ s^{-1}$ ')

plt.errorbar(Temps_2018gep['t_rest'],Temps_2018gep['R'],np.vstack([Temps_2018gep['R'] - Temps_2018gep['R_down'],Temps_2018gep['R_up']-Temps_2018gep['R']])     ,marker = m_sn['2018gep'],fillstyle = f_sn['2018gep'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'b', label = 'SN2018gep')
plt.errorbar(Temps_2022oqm['t_rest'],Temps_2022oqm['R'],np.vstack([Temps_2022oqm['R'] -Temps_2022oqm['R_down'],Temps_2022oqm['R_up']-Temps_2022oqm['R']])      ,marker = m_sn['2022oqm'],fillstyle = f_sn['2022oqm'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'r', label = r'SN2022oqm')
plt.errorbar(Temps_2019hgp['t_rest'],Temps_2019hgp['R'],np.vstack([Temps_2019hgp['R'] -Temps_2019hgp['R_down'],Temps_2019hgp['R_up']-Temps_2019hgp['R']])      ,marker = m_sn['2019hgp'],fillstyle = f_sn['2019hgp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'g', label = r'SN2019hgp')
plt.errorbar(Temps_2020bvc['t_rest'],Temps_2020bvc['R'],np.vstack([Temps_2020bvc['R'] - Temps_2020bvc['R_down'],Temps_2020bvc['R_up']-Temps_2020bvc['R']])     ,marker = m_sn['2020bvc'],fillstyle = f_sn['2020bvc'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'k', label = '2020bvc')
plt.errorbar(Temps_2020oi['t_rest'],Temps_2020oi['R'],np.vstack([Temps_2020oi['R'] - Temps_2020oi['R_down'],Temps_2020oi['R_up']-Temps_2020oi['R']])           ,marker = m_sn['2020oi' ],fillstyle = f_sn['2020oi' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'c', label = '2020oi')
plt.errorbar(Temps_2006aj['t_rest'],Temps_2006aj['R'],np.vstack([Temps_2006aj['R'] - Temps_2006aj['R_down'],Temps_2006aj['R_up']-Temps_2006aj['R']])           ,marker = m_sn['2006aj' ],fillstyle = f_sn['2006aj' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'm', label = '2006aj')
plt.errorbar(Temps_2014ft['t_rest'],Temps_2014ft['R'],np.vstack([Temps_2014ft['R'] - Temps_2014ft['R_down'],Temps_2014ft['R_up']-Temps_2014ft['R']])           ,marker = m_sn['2014ft' ],fillstyle = f_sn['2014ft' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'y', label = '2014ft')
plt.errorbar(Temps_2020scb['t_rest'],Temps_2020scb['R'],np.vstack([Temps_2020scb['R'] - Temps_2020scb['R_down'],Temps_2020scb['R_up']-Temps_2020scb['R']])     ,marker = m_sn['2020scb'],fillstyle = f_sn['2020scb'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#FFB600', label = '2020scb (Ic)')
plt.errorbar(Temps_2021csp['t_rest'],Temps_2021csp['R'],np.vstack([Temps_2021csp['R'] - Temps_2021csp['R_down'],Temps_2021csp['R_up']-Temps_2021csp['R']])     ,marker = m_sn['2021csp'],fillstyle = f_sn['2021csp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#B80043', label = '2021csp (Icn)')
plt.errorbar(Temps_2021gno['t_rest'],Temps_2021gno['R'],np.vstack([Temps_2021gno['R'] - Temps_2021gno['R_down'],Temps_2021gno['R_up']-Temps_2021gno['R']])     ,marker = m_sn['2021gno'],fillstyle = f_sn['2021gno'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#9EDF13', label = '2021gno (Ca-Ib)')
#plt.plot(time,  R2 ,'--r', label =  'v=12,000 $km\ s^{-1}$ ')

plt.xlabel('Rest-frame days from estimated explosion',fontsize = 14)
plt.ylabel('R [cm]',fontsize = 14)
plt.yscale('log')
plt.xscale('log')
#plt.legend(loc = 2)
plt.xlim((0.25,60))
plt.ylim((0.7e14,2.7e16))
plt.tight_layout()
plt.show(block = False)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
#### normalize to arbitrary break time and show broken power law evolution 
tbr = {}
tbr['2022oqm'] = 2.68
tbr['2020bvc'] = 3.3
tbr['2006aj' ] = 5
tbr['2020oi' ] = 3.5
tbr['2018gep'] = 8.5
tbr['2019hgp'] = 4
tbr['2014ft' ] = 1.2
tbr['2020scb' ] = 2.8
tbr['2021csp' ] = 10.8
tbr['2021gno' ] = 4.5

T_norm_2018gep = np.interp(tbr['2018gep'],Temps_2018gep['t_rest'],Temps_2018gep['T'])
T_norm_2022oqm = np.interp(tbr['2022oqm'],Temps_2022oqm['t_rest'],Temps_2022oqm['T'])
T_norm_2019hgp = np.interp(tbr['2019hgp'],Temps_2019hgp['t_rest'],Temps_2019hgp['T'])
T_norm_2020bvc = np.interp(tbr['2020bvc'],Temps_2020bvc['t_rest'],Temps_2020bvc['T'])
T_norm_2020oi  = np.interp(tbr['2020oi' ],Temps_2020oi['t_rest'] ,Temps_2020oi ['T'])
T_norm_2006aj  = np.interp(tbr['2006aj' ],Temps_2006aj['t_rest'] ,Temps_2006aj ['T'])
T_norm_2014ft  = np.interp(tbr['2014ft' ],Temps_2014ft['t_rest'] ,Temps_2014ft ['T'])
T_norm_2020scb  = np.interp(tbr['2020scb' ],Temps_2020scb['t_rest'] ,Temps_2020scb ['T'])
T_norm_2021csp  = np.interp(tbr['2021csp' ],Temps_2021csp['t_rest'] ,Temps_2021csp ['T'])
T_norm_2021gno  = np.interp(tbr['2021gno' ],Temps_2021gno['t_rest'] ,Temps_2021gno ['T'])
L_norm_2018gep = np.interp(tbr['2018gep'],Temps_2018gep['t_rest'],Temps_2018gep['L'])
L_norm_2022oqm = np.interp(tbr['2022oqm'],Temps_2022oqm['t_rest'],Temps_2022oqm['L'])
L_norm_2019hgp = np.interp(tbr['2019hgp'],Temps_2019hgp['t_rest'],Temps_2019hgp['L'])
L_norm_2020bvc = np.interp(tbr['2020bvc'],Temps_2020bvc['t_rest'],Temps_2020bvc['L'])
L_norm_2020oi  = np.interp(tbr['2020oi' ],Temps_2020oi['t_rest'] ,Temps_2020oi ['L'])
L_norm_2006aj  = np.interp(tbr['2006aj' ],Temps_2006aj['t_rest'] ,Temps_2006aj ['L'])
L_norm_2014ft  = np.interp(tbr['2014ft' ],Temps_2014ft['t_rest'] ,Temps_2014ft ['L'])
L_norm_2020scb  = np.interp(tbr['2020scb' ],Temps_2020scb['t_rest'] ,Temps_2020scb ['L'])
L_norm_2021gno = np.interp(tbr['2021gno' ],Temps_2021gno['t_rest'] ,Temps_2021gno ['L'])

markersize = 8


time = np.logspace(-1,0.6,20)

markersize = 6
plt.figure(figsize=(7,10))
#plt.subplot(1,2,1)


plt.plot(time, time**(-1.2)   ,'k-.',alpha = 0.5, label = '')
plt.plot(time, time**(-0.8)   ,'k-.',alpha = 0.5, label = '')
plt.plot(time, time**(-0.5)   ,'k-.',alpha = 0.5, label = '')
plt.plot(time, time**(-0.3)   ,'k-.',alpha = 0.5, label = '')

plt.text(0.14,  0.13**(-1.2)/1.4 ,'$\propto t^{-1.2}\ ^{\circ}K$',color = 'k' ,alpha = 0.8, rotation = -60,fontsize = 14)
plt.text(0.14,  0.13**(-0.8)/1.3 ,'$\propto t^{-0.8}\ ^{\circ}K$',color = 'k' ,alpha = 0.8, rotation = -50,fontsize = 14)
plt.text(0.14,  0.13**(-0.5)/1.25 ,'$\propto t^{-0.5}\ ^{\circ}K$',color = 'k',alpha = 0.8,  rotation = -30,fontsize = 14)
plt.text(0.14,  0.13**(-0.3)/1.2 ,'$\propto t^{-0.3}\ ^{\circ}K$',color = 'k' ,alpha = 0.8, rotation = -20,fontsize = 14)


plt.errorbar(Temps_2018gep['t_rest']/tbr['2018gep'],Temps_2018gep['T']/T_norm_2018gep,(np.vstack([Temps_2018gep['T'] - Temps_2018gep['T_down'],Temps_2018gep['T_up']-Temps_2018gep['T']]))/T_norm_2018gep         ,marker = m_sn['2018gep'],fillstyle = f_sn['2018gep'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'b', label = '2018gep (Ic-BL)')
plt.errorbar(Temps_2022oqm['t_rest']/tbr['2022oqm'],Temps_2022oqm['T']/T_norm_2022oqm,(np.vstack([Temps_2022oqm['T'] -Temps_2022oqm['T_down'],Temps_2022oqm['T_up'] -Temps_2022oqm['T']]))/T_norm_2022oqm         ,marker = m_sn['2022oqm'],fillstyle = f_sn['2022oqm'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'r', label = r'SN2022oqm (Ic)')
plt.errorbar(Temps_2019hgp['t_rest']/tbr['2019hgp'],Temps_2019hgp['T']/T_norm_2019hgp,(np.vstack([Temps_2019hgp['T'] -Temps_2019hgp['T_down'],Temps_2019hgp['T_up'] -Temps_2019hgp['T']]))/T_norm_2019hgp         ,marker = m_sn['2019hgp'],fillstyle = f_sn['2019hgp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'g', label = r'SN2019hgp (Icn)')
plt.errorbar(Temps_2020bvc['t_rest']/tbr['2020bvc'],Temps_2020bvc['T']/T_norm_2020bvc,(np.vstack([Temps_2020bvc['T'] - Temps_2020bvc['T_down'],Temps_2020bvc['T_up']-Temps_2020bvc['T']]))/T_norm_2020bvc         ,marker = m_sn['2020bvc'],fillstyle = f_sn['2020bvc'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'k', label = '2020bvc (Ic-BL)')
plt.errorbar(Temps_2020oi ['t_rest']/tbr['2020oi' ],Temps_2020oi ['T']/T_norm_2020oi ,(np.vstack([Temps_2020oi['T'] - Temps_2020oi['T_down'],Temps_2020oi['T_up']-Temps_2020oi['T']])    )/T_norm_2020oi          ,marker = m_sn['2020oi' ],fillstyle = f_sn['2020oi' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'c', label = '2020oi (Ic)')
plt.errorbar(Temps_2006aj ['t_rest']/tbr['2006aj' ],Temps_2006aj ['T']/T_norm_2006aj ,(np.vstack([Temps_2006aj['T'] - Temps_2006aj['T_down'],Temps_2006aj['T_up']-Temps_2006aj['T']])    )/T_norm_2006aj          ,marker = m_sn['2006aj' ],fillstyle = f_sn['2006aj' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'm', label = '2006aj (Ic-BL)')
plt.errorbar(Temps_2014ft ['t_rest']/tbr['2014ft' ],Temps_2014ft ['T']/T_norm_2014ft ,(np.vstack([Temps_2014ft['T'] - Temps_2014ft['T_down'],Temps_2014ft['T_up']-Temps_2014ft['T']])    )/T_norm_2014ft          ,marker = m_sn['2014ft' ],fillstyle = f_sn['2014ft' ],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = 'y', label = '2014ft (US-Ic)')
plt.errorbar(Temps_2020scb['t_rest']/tbr['2020scb' ],Temps_2020scb ['T']/T_norm_2020scb ,(np.vstack([Temps_2020scb['T'] - Temps_2020scb['T_down'],Temps_2020scb['T_up']-Temps_2020scb['T']])    )/T_norm_2020scb  ,marker = m_sn['2020scb'],fillstyle = f_sn['2020scb'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#FFB600', label = '2020scb (Ic)')
plt.errorbar(Temps_2021csp['t_rest']/tbr['2021csp' ],Temps_2021csp ['T']/T_norm_2021csp ,(np.vstack([Temps_2021csp['T'] - Temps_2021csp['T_down'],Temps_2021csp['T_up']-Temps_2021csp['T']])    )/T_norm_2021csp  ,marker = m_sn['2021csp'],fillstyle = f_sn['2021csp'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#B80043', label = '2021csp (Icn)')
plt.errorbar(Temps_2021gno['t_rest']/tbr['2021gno'],Temps_2021gno['T']/T_norm_2021gno,(np.vstack([Temps_2021gno['T'] - Temps_2021gno['T_down'],Temps_2021gno['T_up']-Temps_2021gno['T']])    )/T_norm_2021gno ,marker = m_sn['2021gno'],fillstyle = f_sn['2021gno'],markersize = markersize,ls = '--', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5), color = '#9EDF13', label = '2021gno (Ca-Ib)')
plt.xlabel(r'$t/t_{br}$',fontsize = 14)
plt.ylabel(r'$T/T (t_{br})$',fontsize = 14)
plt.yscale('log')
plt.xscale('log')
plt.xlim((0.1,5))
plt.ylim((0.3,20))
plt.legend(fontsize = 14)
plt.show(block = False)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
T =    time**(-1.2)   
T2 =   time**(-0.5)
Tgep = time**(-0.8)   
R = time*1e4
R2 = 5e14+ 1.2e9*time*3600*24
R3 = (time*3600*24)**(0.68)
T3 = time**(-0.32)
T4 = time**(-0.5)
L1 = time**(-0.95)
L2 = time**(-2.5)
L3 = time**(-1.74)


time = np.logspace(-0.5,3,100)

best_Ni = np.array([ 8.3401702 ,  0.10353397, 42.37782697]) #best fir from day 12 
L4 = LSN_Ni56(Temps_2022oqm['t_rest'],best_Ni[0], Mni = best_Ni[1],t0 = best_Ni[2], kappa=0.07) 
L2 = time**(-2.5)
marker = '*'
markersize = 6
Temps_2022oqm['t_rest'] = (Temps_2022oqm['JD']-t0_oqm)/(1+0.0113)-0.13589
L4 = LSN_Ni56(time,10, Mni = 0.106,t0 = 36, kappa=0.1) 
L44= LSN_Ni56(Temps_2022oqm['t_rest'],10, Mni = 0.106,t0 = 36, kappa=0.1) 
L2 = time**(-1.74)
cond_t = (Temps_2022oqm['t_rest']<40)#|(Temps_2022oqm['t_rest']>63)



plt.figure(figsize=(6,8))

plt.errorbar(Temps_2022oqm[cond_t]['t_rest'],Temps_2022oqm[cond_t]['L_bol_w_extrap'],Temps_2022oqm[cond_t]['L_bol_w_extrap_err'],marker = 'o',ls = '', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'r', label = r'SN2022oqm +IR/UV extrapolation')
plt.errorbar(Temps_2022oqm['t_rest'],Temps_2022oqm['Psudo_L_bol'],Temps_2022oqm['Pseudo_L_bol_err'],marker = 'o',ls = '', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'y', label = r'optical pseudo-bolometric')
plt.errorbar(Temps_2022oqm['t_rest'][-1],Temps_2022oqm['Psudo_L_bol'][-1],Temps_2022oqm['Pseudo_L_bol_err'][-1],marker = 'P',ls = '', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'k', label = r'optical + JHK  Pseudo bolometric')
plt.errorbar(Temps_2022oqm['t_rest'][-1],1.85*Temps_2022oqm['Psudo_L_bol'][-1],Temps_2022oqm['Pseudo_L_bol_err'][-1],marker = 'o',ls = '', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = '#E89700', label = r'optical + JHK  Pseudo bolometric + IR extrapolation')

plt.xlabel('Rest-frame days from estimated explosion',fontsize = 14)
plt.ylabel('L [erg/s]',fontsize = 14)

plt.errorbar(Temps_2022oqm[cond_t]['t_rest'],Temps_2022oqm[cond_t]['L_bol_w_extrap']-L44[cond_t],Temps_2022oqm[cond_t]['L_bol_w_extrap_err'],marker = 'o',ls = '', elinewidth=2.5, ecolor= (0.5,0.5,0.5,0.5) , color = 'g', label = r'SN2022oqm - L$_{Ni^{56}}$')

plt.plot(time,L4,'k--',label = 'Best fit')
#plt.plot(time,L444*1.145,'g--',label = 'Deposition')
plt.xlim((0.5*np.min(Temps_2022oqm['t_rest']),1.2*np.max(Temps_2022oqm['t_rest'])))
plt.yscale('log')
plt.xscale('log')
plt.legend()

plt.show(block = False)

# %%
data22oqm = data22oqm[data22oqm['isdet'] == 'True']
data22oqm = data22oqm[data22oqm['t'] >0]

data22oqm['t_rest'] = data22oqm['t']/(1+z)
dat = data22oqm.copy()
dat['filter_orig'] = data22oqm['filter']
import scipy
data22oqm['filter_orig']= data22oqm['filter']
data22oqm['filter'][data22oqm['filter']=='g_P60'] = 'ZTF_g'
data22oqm['filter'][data22oqm['filter']=='LT_g'] = 'ZTF_g'
data22oqm['filter'][data22oqm['filter']=='r_P60'] = 'ZTF_r'
data22oqm['filter'][data22oqm['filter']=='LT_r'] = 'ZTF_r'
data22oqm['filter'][data22oqm['filter']=='i_P60'] = 'ZTF_i'
data22oqm['filter'][data22oqm['filter']=='LT_i'] = 'ZTF_i'
data22oqm['filter'][data22oqm['filter']=='u_P60'] = 'u_swift'
data22oqm['filter'][data22oqm['filter']=='LT_u'] = 'u_swift'
